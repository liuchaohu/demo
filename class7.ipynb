# %% [markdown]
# # Pandas
# pandas提供三个数据结构
# - 系列 Series  1维
# - 数据帧 DataFrame  2维
# - 面板 Panel 3维
# 这些数据结构都建立在numpy上，速度很快

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('2019级.xlsx')

# %%
import pandas as pd
import numpy as np

s = pd.Series([1, 3, 5, np.nan, 6, 8])
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
dates = pd.date_range('20210226', periods=7)
print(dates)
# Out:
# DatetimeIndex(['2021-02-26', '2021-02-27', '2021-02-28', '2021-03-01',
#                '2021-03-02', '2021-03-03', '2021-03-04'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(7, 4), index=dates, columns=list('ABCD'))
print(df)  # 先列再行
# Out:
#                    A         B         C         D
# 2021-02-26  1.323538 -0.440627 -0.009899 -0.978747
# 2021-02-27 -0.978645 -1.116997 -0.417711 -0.850420
# 2021-02-28  1.417317  0.873957  1.022174  0.343263
# 2021-03-01 -1.325525 -0.090749  1.538521 -0.489378
# 2021-03-02  0.179310  0.798606 -0.172773  0.979868
# 2021-03-03  0.968264  0.913927  0.110077 -0.875586
# 2021-03-04 -0.262329 -1.041182 -2.172917 -0.844496

# %%
import pandas as pd
import numpy as np

df2 = pd.DataFrame({
    'A' : 1,
    'B' : pd.Timestamp('20210226'),
    'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
    'D' : np.array([4] * 4,dtype='int32'),
    'E' : pd.Categorical(["test","train","test","train"]),
    'F' : 'foo'
})
df2
# Out:
#    A          B    C  D      E    F
# 0  1 2021-02-26  1.0  4   test  foo
# 1  1 2021-02-26  1.0  4  train  foo
# 2  1 2021-02-26  1.0  4   test  foo
# 3  1 2021-02-26  1.0  4  train  foo

# %%
import pandas as pd
import numpy as np
dates = pd.date_range('20211212', periods=7)
df = pd.DataFrame(np.random.randn(7, 4), index=dates, columns=list('ABCD'))
df.index
df.columns
print(df.values)
# Out:
# [[-0.02906166  0.92706036 -2.02753287 -0.99626272]
#  [-0.09141155 -1.82898984 -0.170237   -1.24838122]
#  [-0.33186639  0.64499005  1.18729564  1.68463269]
#  [ 1.60509197  0.39412005  0.40686909 -1.99863826]
#  [ 0.22200579  1.04477826  0.2771637  -1.50345771]
#  [-2.29186758 -0.46598038 -1.20214209  0.8629492 ]
#  [-0.08290567 -0.13638589  0.43151661  0.51970798]]

# %%
dates = pd.date_range('20170101', periods=7)
df = pd.DataFrame(np.random.randn(7,4), index=dates, columns=list('ABCD'))
print(df.describe())
# Out:
#               A         B         C         D
# count  7.000000  7.000000  7.000000  7.000000
# mean   0.354100  0.019587  0.019494 -0.579937
# std    0.690159  0.912781  1.007416  1.272988
# min   -0.541105 -1.227316 -1.447645 -3.015974
# 25%   -0.128663 -0.681397 -0.434647 -0.841074
# 50%    0.258201  0.381154 -0.351547 -0.463672
# 75%    0.795899  0.470440  0.691587 -0.024633
# max    1.427131  1.405183  1.421767  1.151501

# %%
df.T # 转置
# Out:
#    2017-01-01  2017-01-02  2017-01-03  2017-01-04  2017-01-05  2017-01-06  \
# A    1.427131    0.808958    0.782840   -0.541105   -0.268481    0.258201
# B    0.504691   -1.227316    1.405183   -0.649763    0.436188   -0.713032
# C   -0.469369    0.184405   -0.399924   -1.447645   -0.351547    1.421767
# D   -0.766938    1.151501   -0.915210   -3.015974   -0.105903   -0.463672
#
#    2017-01-07
# A    0.011155
# B    0.381154
# C    1.198768
# D    0.056637

# %%
dates = pd.date_range('20170101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
# 按轴的名字排序
print(df.sort_index(axis=1, ascending=False))
# Out:
#                    D         C         B         A
# 2017-01-01  1.525297 -1.188209  0.939964 -0.119071
# 2017-01-02 -0.711547 -0.548698 -1.172640 -1.712734
# 2017-01-03 -0.026752  0.797045 -0.748612  0.544436
# 2017-01-04 -0.641701  2.020122 -0.740171  1.571144
# 2017-01-05 -0.071038  2.330639  0.758481  0.250035
# 2017-01-06  0.547800  1.201409 -1.076964 -1.530397

# %%
import pandas as pd
import numpy as np

dates = pd.date_range('20170101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
print(df.sort_values(by='B', ascending=False))
# Out:
#                    A         B         C         D
# 2017-01-06  0.141350  1.502620  0.907911  0.384523
# 2017-01-03  0.132308  1.422303 -0.314678 -1.235661
# 2017-01-05 -1.034497  0.761668 -0.195419 -2.310229
# 2017-01-04  0.099809 -0.421772 -1.094435  0.920545
# 2017-01-02 -0.122358 -0.879457 -0.314549 -0.549048
# 2017-01-01 -1.380787 -1.259600 -1.640784 -0.043796

# %%
import pandas as pd
import numpy as np

dates = pd.date_range('20170101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
print(df)
print(df['A'])

print(df[0:3]) # 行
print(df['20170102':"20170103"])
# Out:
#                    A         B         C         D
# 2017-01-01  0.158094 -1.128560 -0.449934  2.067265
# 2017-01-02  1.551210 -1.823057 -0.827461  0.002927
# 2017-01-03  0.953780 -0.289000 -0.942463  0.556164
# 2017-01-04  0.202753 -1.249621 -0.083376  0.000291
# 2017-01-05 -1.175075  0.779959 -0.512817 -0.806053
# 2017-01-06  0.709852 -0.833383 -0.927146 -0.054549
# 2017-01-01    0.158094
# 2017-01-02    1.551210
# 2017-01-03    0.953780
# 2017-01-04    0.202753
# 2017-01-05   -1.175075
# 2017-01-06    0.709852
# Freq: D, Name: A, dtype: float64
#                    A         B         C         D
# 2017-01-01  0.158094 -1.128560 -0.449934  2.067265
# 2017-01-02  1.551210 -1.823057 -0.827461  0.002927
# 2017-01-03  0.953780 -0.289000 -0.942463  0.556164
#                   A         B         C         D
# 2017-01-02  1.55121 -1.823057 -0.827461  0.002927
# 2017-01-03  0.95378 -0.289000 -0.942463  0.556164

# %%
import pandas as pd
import numpy as np

dates = pd.date_range('20170101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
print(df)
print(df.loc[dates[0]])
# Out:
#                    A         B         C         D
# 2017-01-01  0.707399  0.426375  0.682594 -0.160137
# 2017-01-02 -0.114376  1.570186  0.172505  0.035918
# 2017-01-03  0.438118 -0.064168 -2.635838 -0.169389
# 2017-01-04  0.015479  0.047236  0.626466  0.613780
# 2017-01-05 -0.493737  0.427977  1.159258 -0.256670
# 2017-01-06 -0.674420  0.414563  0.935386 -1.475772
# A    0.707399
# B    0.426375
# C    0.682594
# D   -0.160137
# Name: 2017-01-01 00:00:00, dtype: float64

# %%
import pandas as pd
import numpy as np

dates = pd.date_range('20170101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

print(df.loc[:,['A','B']])
# Out:
#                    A         B
# 2017-01-01  1.567282  0.325382
# 2017-01-02 -0.697590  0.773944
# 2017-01-03  1.105168  0.785863
# 2017-01-04  0.159952  1.045594
# 2017-01-05  0.323429  0.497738
# 2017-01-06 -0.286552  0.378260

# %%
import pandas as pd
import numpy as np

dates = pd.date_range('20170101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
#　现实端点
print(df.loc['20170102':'20170104',['A','B']])
# Out:
#                    A         B
# 2017-01-02 -0.295221  0.883744
# 2017-01-03 -0.530091  0.434349
# 2017-01-04  2.127865 -1.680782

# %%
import pandas as pd
import numpy as np

dates = pd.date_range('20170101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

print(df.iloc[5])
# Out:
# A    0.566425
# B   -1.626061
# C    1.569873
# D    1.783950
# Name: 2017-01-06 00:00:00, dtype: float64

# %%
import pandas as pd
import numpy as np

dates = pd.date_range('20170101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

print(df.iloc[3:5,0:2])
# Out:
#                    A         B
# 2017-01-04  1.538823 -0.727218
# 2017-01-05  2.491796 -0.501403

# %%
# bool 索值
import pandas as pd
import numpy as np

dates = pd.date_range('20170101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

print(df[df > 0])
# Out:
#                    A         B         C         D
# 2017-01-01  1.063054       NaN  0.447709  1.681022
# 2017-01-02  0.042604  0.443360       NaN       NaN
# 2017-01-03       NaN  0.904685  0.852254       NaN
# 2017-01-04       NaN       NaN  0.207270       NaN
# 2017-01-05       NaN  0.746394  1.003692  1.890728
# 2017-01-06       NaN  1.362263  0.528876  1.948960

# %%
# Series
# pandas.Series(data, index, dtype, copy)

# 创建空数列
import pandas as pd
s = pd.Series()
print(s)
# Out:
# Series([], dtype: float64)

# %%
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data)
print(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data, index=[100,101,102,103])
print(s)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
import pandas as pd
import numpy as np
# 用字典
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data)
print(s)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
# 用标量创建
s = pd.Series(5, index=[0, 1, 2, 3])
print(s)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])

#retrieve multiple elements
s[['a','c','d']]
# Out:
# a    1
# c    3
# d    4
# dtype: int64

# %%
# DataFrame
# pandas.DataFrame( data, index, columns, dtype, copy)
#import the pandas library and aliasing as pd
import pandas as pd
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
data = [1,2,3,4,5]
df = pd.DataFrame(data)
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %%
import pandas as pd
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df = pd.DataFrame(data)
print(df)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
import pandas as pd

d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']), 
     'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']), 
     'three' : pd.Series([10,20,30], index=['a','b','c'])}

df = pd.DataFrame(d)
print(df)
del df['one']
print(df)
df.pop('two')
print(df)
# Out:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
#    two  three
# a    1   10.0
# b    2   20.0
# c    3   30.0
# d    4    NaN
#    three
# a   10.0
# b   20.0
# c   30.0
# d    NaN

# %%
import pandas as pd

d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
      'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
df['three']=pd.Series([10,20,30],index=['a','b','c'])
print(df)
# Out:
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN

# %%
# 行切片
import pandas as pd

d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']), 
    'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
print(df)
print(df[2:4])
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
#    one  two
# c  3.0    3
# d  NaN    4

# %%
# 增加一行数据
import pandas as pd

df = pd.DataFrame([[1, 2], [3, 4]], columns = ['a','b'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a','b'])

df = df.append(df2)
print(df)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8

# %%
import pandas as pd

df = pd.DataFrame([[1, 2], [3, 4]], columns = ['a','b'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a','b'])

df = df.append(df2)
print(df)
# Drop rows with label 0
df = df.drop(0)

print(df)
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 0  5  6
# 1  7  8
#    a  b
# 1  3  4
# 1  7  8

# %%
# pandas基本功能

# 返回行轴标签列表
import pandas as pd
import numpy as np
s = pd.Series(np.random.randn(4))
print(s)
print(s.axes)
# Out:
# 0   -1.052729
# 1    0.184336
# 2    0.839921
# 3    0.560012
# dtype: float64
# [RangeIndex(start=0, stop=4, step=1)]

# %%
import pandas as pd
import numpy as np
# 判断是否空
s = pd.Series(np.random.randn(4))
print(s.empty)
# Out:
# False

# %%
import pandas as pd
import numpy as np

# 返回对象的维数
s = pd.Series(np.random.randn(4))
print(s)
print(s.ndim)
# Out:
# 0   -3.364533
# 1    0.073169
# 2    1.585620
# 3   -0.400321
# dtype: float64
# 1

# %%
import pandas as pd
import numpy as np

#Create a series with 4 random numbers
s = pd.Series(np.random.randn(2))
print(s)
print(s.size)
# Out:
# 0   -0.240484
# 1    0.116820
# dtype: float64
# 2

# %%
s = pd.Series(np.random.randn(4))
print(s)
# 返回数值
print(s.values)
# Out:
# 0   -0.986465
# 1    0.269839
# 2    2.683891
# 3    0.278826
# dtype: float64
# [-0.98646509  0.26983929  2.68389101  0.27882608]

# %%
s = pd.Series(np.random.randn(4))
print(s)
print(s.head(2)) # 返回前n行
# Out:
# 0    0.743048
# 1    0.753193
# 2    1.912757
# 3    0.500184
# dtype: float64
# 0    0.743048
# 1    0.753193
# dtype: float64

# %%
s = pd.Series(np.random.randn(4))
print(s)
print(s.tail(2)) # 返回后n行
# Out:
# 0    1.176298
# 1    0.087648
# 2   -0.091256
# 3    0.358359
# dtype: float64
# 2   -0.091256
# 3    0.358359
# dtype: float64

# %%
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Minsu','Jack']),
   'Age':pd.Series([25,26,25,23,30,29,23]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8])}
df = pd.DataFrame(d)
print(df)
print(df.shape)
# Out:
#     Name  Age  Rating
# 0    Tom   25    4.23
# 1  James   26    3.24
# 2  Ricky   25    3.98
# 3    Vin   23    2.56
# 4  Steve   30    3.20
# 5  Minsu   29    4.60
# 6   Jack   23    3.80
# (7, 3)

# %%
import pandas as pd
import numpy as np

#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Minsu','Jack']),
   'Age':pd.Series([25,26,25,23,30,29,23]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8])}
df = pd.DataFrame(d)
print(df)
print(df.size)
# Out:
#     Name  Age  Rating
# 0    Tom   25    4.23
# 1  James   26    3.24
# 2  Ricky   25    3.98
# 3    Vin   23    2.56
# 4  Steve   30    3.20
# 5  Minsu   29    4.60
# 6   Jack   23    3.80
# 21

# %%
# 描述性统计
import pandas as pd
import numpy as np

#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Minsu','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])}
df = pd.DataFrame(d)
print(df.sum())
# Out:
# Name      TomJamesRickyVinSteveMinsuJackLeeDavidGasperBe...
# Age                                                     382
# Rating                                                44.92
# dtype: object

# %%
import pandas as pd
import numpy as np

#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Minsu','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])}

df = pd.DataFrame(d)
print(df.std())
# Out:
# Age       9.232682
# Rating    0.661628
# dtype: float64

# %%
import pandas as pd
import numpy as np

N=20

df = pd.DataFrame({
    'A': pd.date_range(start='2016-01-01',periods=N,freq='D'),
    'x': np.linspace(0,stop=N-1,num=N),
    'y': np.random.rand(N),
    'C': np.random.choice(['Low','Medium','High'],N).tolist(),
    'D': np.random.normal(100, 10, size=(N)).tolist()
    })
#　遍历列标签
for col in df:
   print(col)
# Out:
# A
# x
# y
# C
# D

# %%
import pandas as pd
import numpy as np
# 将列作为键，每一列的值作为值
df = pd.DataFrame(np.random.randn(4,3),columns=['col1','col2','col3'])
for key,value in df.iteritems():
   print (key,value)
# Out:
# col1 0   -0.262719
# 1   -0.624475
# 2    0.017224
# 3    0.546297
# Name: col1, dtype: float64
# col2 0   -0.913495
# 1   -0.126492
# 2    0.427375
# 3   -0.470441
# Name: col2, dtype: float64
# col3 0    0.204922
# 1   -0.583586
# 2   -1.364439
# 3   -2.796030
# Name: col3, dtype: float64

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(4,3),columns = ['col1','col2','col3'])
for row_index,row in df.iterrows():
   print(row_index, row)
# Out:
# 0 col1   -1.549525
# col2   -0.508890
# col3   -0.307570
# Name: 0, dtype: float64
# 1 col1   -0.250947
# col2    0.089532
# col3    0.596947
# Name: 1, dtype: float64
# 2 col1   -0.726689
# col2   -0.426799
# col3    0.715331
# Name: 2, dtype: float64
# 3 col1    1.192500
# col2    0.510698
# col3   -1.722840
# Name: 3, dtype: float64

# %%
import pandas as pd
import numpy as np

unsorted_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns = ['col2','col1'])

sorted_df=unsorted_df.sort_index()
print (sorted_df)
# Out:
#        col2      col1
# 0 -0.985810 -0.072145
# 1  1.060351  0.524585
# 2 -0.712856  0.512434
# 3 -1.020107  0.061644
# 4  0.382996  0.254231
# 5  0.972723  0.467853
# 6 -0.590786  0.444283
# 7 -0.821130 -0.922914
# 8 -1.380503  0.682287
# 9  0.924676  2.159942

# %%
import pandas as pd
import numpy as np
# 按列名字
unsorted_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns = ['col2','col1'])
sorted_df=unsorted_df.sort_index(axis=1)
print (sorted_df)
# Out:
#        col1      col2
# 1  2.132530  1.384954
# 4  0.940087 -0.023518
# 6 -0.069362 -0.101086
# 2  1.059952 -2.444272
# 3  1.981718  0.176633
# 5 -0.370055  1.830736
# 9 -1.024940 -0.741771
# 8  1.831855  0.838880
# 0  1.390449 -0.528517
# 7 -0.190738 -0.293010

# %%
import pandas as pd
import numpy as np

unsorted_df = pd.DataFrame({'col1':[2,1,1,1],'col2':[1,3,2,4]})
sorted_df = unsorted_df.sort_values(by='col1')

print (sorted_df)
# Out:
#    col1  col2
# 1     1     3
# 2     1     2
# 3     1     4
# 0     2     1

# %%
# 统计函数
# 协方差
# 适用于 系列数据
import pandas as pd
import numpy as np
s1 = pd.Series(np.random.randn(10))
s2 = pd.Series(np.random.randn(10))
print (s1.cov(s2))
# Out:
# 0.1716920430377385

# %%
import pandas as pd
import numpy as np
# 得到每一列之间的协方差
frame = pd.DataFrame(np.random.randn(10, 5), columns=['a', 'b', 'c', 'd', 'e'])
print (frame['a'].cov(frame['b']))
print (frame.cov())
# Out:
# 0.18691337459474022
#           a         b         c         d         e
# a  1.675765  0.186913  0.225115  0.366523 -0.003064
# b  0.186913  0.966954  0.050654 -0.435118  0.124660
# c  0.225115  0.050654  0.502474  0.108766  0.096635
# d  0.366523 -0.435118  0.108766  1.819210 -0.691493
# e -0.003064  0.124660  0.096635 -0.691493  1.307509

# %%
import pandas as pd
import numpy as np
frame = pd.DataFrame(np.random.randn(10, 5), columns=['a', 'b', 'c', 'd', 'e'])
# 相关性
print (frame['a'].corr(frame['b']))
print (frame.corr())
# Out:
# -0.4175859496985766
#           a         b         c         d         e
# a  1.000000 -0.417586  0.286739 -0.159749  0.444100
# b -0.417586  1.000000 -0.165323 -0.141314  0.265680
# c  0.286739 -0.165323  1.000000 -0.285659  0.406696
# d -0.159749 -0.141314 -0.285659  1.000000 -0.355764
# e  0.444100  0.265680  0.406696 -0.355764  1.000000

# %%
import pandas as pd
datelist = pd.date_range('2020/11/21', periods=5)
print(datelist)
# Out:
# DatetimeIndex(['2020-11-21', '2020-11-22', '2020-11-23', '2020-11-24',
#                '2020-11-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
# 增加日期频率
datelist = pd.date_range('2020/11/21', periods=5,freq='M')
print(datelist)
# Out:
# DatetimeIndex(['2020-11-30', '2020-12-31', '2021-01-31', '2021-02-28',
#                '2021-03-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
# 可视化
# plt 包装
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('2018/12/18',
   periods=10), columns=list('ABCD'))

df.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

df.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])
df.plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

df.hist(bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>, <AxesSubplot:>]], dtype=object)

# %%
import pandas as pd
import numpy as np
# 箱型图
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], columns=['x'])
df.plot.pie(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='x'>], dtype=object)
